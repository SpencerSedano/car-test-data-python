# %%
import pandas as pd

# %%
pd.read_csv(
    "C:/Users/spenc/OneDrive/Desktop/python-car-test-data/python-car-test-data/true-false-questions/output/output3_all_pages.csv",
    on_bad_lines="warn",
)
# Out:
#     Number Answer                                           Question
# 0      001      O  Valuing life should be the top priority of dri...
# 1      002      X  Abiding by the traffic regulations has nothing...
# 2      003      O  A gasoline fire should be put out by a fire ex...
# 3      004      O  Yielding and tolerance are indicators of good ...
# 4      005      O  You should yield to oncoming vehicles on a nar...
# ..     ...    ...                                                ...
# 645    650      O  In the case of a car accident on a freeway in ...
# 646    651      O  If a car has a traffic accident on a freeway, ...
# 647    652      O  If a car breaks down or has an accident on a f...
# 648    653      O  If a car breaks down or has an accident on a f...
# 649    654      O  Starting from June 30th, 2023, newly obtained ...
#
# [650 rows x 3 columns]
